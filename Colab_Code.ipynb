# %%
# !python /content/omega_gpu_benchmark_colab.py \
    --sizes 1024 4096 16384 65536 262144 1048576 \
    --ratio 4.2 \
    --iters 200 \
    --csv omega_gpu_results.csv
# Out:
# Backend: CUDA
# GPU: NVIDIA A100-SXM4-40GB
# CuPy: 14.0.1
# CUDA runtime: 12090
# CUDA driver: 13000
# backend,n_vars,n_clauses,n_nodes,nnz_offdiag,iterations,elapsed_ms,GedgeVisits/s,ns/edge/iter,MiB,clause_fraction,sat_found
# cuda,1024,4301,5325,25780,200,331.496,0.016,64.293340,0.30,0.88444548,0
# cuda,4096,17203,21299,103198,200,9.495,2.174,0.460015,1.19,0.87507993,0
# cuda,16384,68813,85197,412840,200,9.376,8.807,0.113552,4.77,0.87548864,0
# cuda,65536,275251,340787,1651498,200,11.167,29.579,0.033808,19.10,0.87575704,0
# cuda,262144,1101005,1363149,6605998,200,35.250,37.481,0.026680,76.40,0.87456369,0
# cuda,1048576,4404019,5452595,26424080,200,140.588,37.591,0.026602,305.60,0.87490858,0
#
# Saved benchmark CSV to: omega_gpu_results.csv
